# %% [markdown]
# **Problem 1: Social Media – Post Engagement Analyzer**
# - Problem Statement
#     - Create a function to analyze engagement on a social media post.
# - Rules
#     - Calculate total likes
#     - If Total Likes ≥ 1000 → Viral Post
#     - Otherwise → Normal Engagement
# - Real-Time Use
#     - Social media analytics platforms
#     - Marketing dashboards
# - Expected Output Format
#     - Total Likes: 1050
#     - Post Status: Viral Post

# %%
def analyze_engagement(likes_list):
    total_likes = 0
    for like in likes_list:
        total_likes += like

    if total_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"

    print("Total Likes:", total_likes)
    print("Post Status:", status)
user_input = input("Enter likes separated by spaces: ") #Sample input: [200, 300, 150, 400]
likes = [int(x) for x in user_input.split()]
analyze_engagement(likes)
# Out:
# Total Likes: 1050
# Post Status: Viral Post

# %% [markdown]
# **Problem 2: Healthcare – Medicine Stock Alert System**
# - Problem Statement
#     - Create a function to monitor medicine stock levels.
# - Rules
#     - Stock < 10 → Low Stock Alert
#     - Stock ≥ 10 → Stock Sufficient
# - Real-Time Use
#     - Pharmacy management systems
#     - Hospital inventory tracking
# - Expected Output Format
#     - Medicine Stock: 6
#     - Status: Low Stock Alert

# %%
def check_medicine_stock(stock):
    if stock < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"
    print("Medicine Stock:", stock)
    print("Status:", status)
stock_value = int(input("Enter current medicine stock: ")) #Sample input: 8
check_medicine_stock(stock_value)
# Out:
# Medicine Stock: 8
# Status: Low Stock Alert

# %% [markdown]
# **Problem 3: Agriculture – Rainfall Adequacy Checker**
# - Problem Statement
#     - Create a function that analyzes seasonal rainfall data.
# - Rules
#     - Calculate average rainfall
#     - Average ≥ required level → Adequate Rainfall
#     - Otherwise → Inadequate Rainfall
# - Real-Time Use
#     - Climate monitoring systems
#     - Irrigation planning tools
# - Expected Output Format
#     - Average Rainfall: 72
#     - Rainfall Status: Adequate Rainfall

# %%
def rainfall_checker(rainfall_data):
    total = 0
    for rain in rainfall_data:
        total += rain
    average = total / len(rainfall_data)
    if average >= 70:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"
    print("Average Rainfall:", average)
    print("Rainfall Status:", status)
rain_input = input("Enter rainfall values separated by comma: ") #Sample input: ["80, 60, 75, 90"]
rainfall_list = [float(x) for x in rain_input.split(",")]
rainfall_checker(rainfall_list)
# Out:
# Average Rainfall: 76.25
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# **Problem 4: Social Media – Duplicate Account Detection**
# - Problem Statement
#     - Create a function to detect duplicate usernames in a system.
# - Rules
#     - If duplicates exist → Flag accounts
#     - Else → Accounts are unique
# - Real-Time Use
#     - Platform moderation
#     - Fraud detection systems
# - Expected Output Format
#     - Duplicate Accounts Found: Yes

# %%
def detect_duplicates(usernames):
    if len(usernames) != len(set(usernames)):
        print("Duplicate Accounts Found: Yes")
    else:
        print("Duplicate Accounts Found: No")
user_input = input("Enter usernames separated by comma: ")
username_list = user_input.split(",") #sample input: ["user1", "user2", "user3", "user1"]
detect_duplicates(username_list)
# Out:
# Duplicate Accounts Found: Yes

# %% [markdown]
# **Problem 5: Healthcare – Appointment Eligibility Checker**
# - Problem Statement
#     - Create a function to check whether a patient is eligible for an appointment slot.
# - Rules
#     - Age ≥ 18 → Eligible
#     - Age < 18 → Not Eligible
# - Real-Time Use
#     - Hospital appointment systems
#     - Healthcare portals
# - Expected Output Format
#     - Patient Age: 21
#     - Eligibility Status: Eligible

# %%
def check_appointment_eligibility(age):
    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"
    print("Patient Age:", age)
    print("Eligibility Status:", status)
patient_age = int(input("Enter patient age: ")) #sample input: 20
check_appointment_eligibility(patient_age)
# Out:
# Patient Age: 20
# Eligibility Status: Eligible

# %% [markdown]
# **Problem 6: Agriculture – Premium Crop Price Filter**
# - Problem Statement
#     - Create a function that filters crop prices above a premium threshold.
# - Rules
#     - Price > ₹2000 → Premium Crop
#     - Else → Regular Crop
# - Real-Time Use
#     - Market analytics
#     - Export pricing systems
# - Expected Output Format
#     - Premium Crops: [2500, 3200]

# %%
def filter_premium_crops(prices):
    premium = []
    for price in prices:
        if price > 2000:
            premium.append(price)
    print("Premium Crops:", premium)
user_input = input("Enter crop prices separated by comma: ") #Sample input: [1500, 2500, 3000, 1800, 2200]
price_list = [int(x) for x in user_input.split(",")]
filter_premium_crops(price_list)
# Out:
# Premium Crops: [2500, 3000, 2200]

# %% [markdown]
# **Problem 7: System Monitoring – Application Health Checker**
# - Problem Statement
#     - Create a function to evaluate application health based on error count.
# - Rules
#     - Errors = 0 → Healthy
#     - Errors ≤ 5 → Minor Issues
#     - Errors > 5 → Critical Issues
# - Real-Time Use
#     - System monitoring tools
#     - IT operations dashboards
# - Expected Output Format
#     - Error Count: 7
#     System Status: Critical Issues

# %%
#case 1: 0 errors (healthy) ) 
def check_system_health(errors):
    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"
    print("Error Count:", errors)
    print("System Status:", status)
error_count = int(input("Enter error count: "))
check_system_health(error_count)
# Out:
# Error Count: 0
# System Status: Healthy

# %%
#case 2: 3 errors (minor issues)
def check_system_health(errors):
    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"
    print("Error Count:", errors)
    print("System Status:", status)
error_count = int(input("Enter error count: "))
check_system_health(error_count)
# Out:
# Error Count: 3
# System Status: Minor Issues

# %%
#case 3: 10 errors (critical issues)
def check_system_health(errors):
    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"
    print("Error Count:", errors)
    print("System Status:", status)
error_count = int(input("Enter error count: "))
check_system_health(error_count)
# Out:
# Error Count: 10
# System Status: Critical Issues

# %% [markdown]
# **Problem 8: Banking – Daily Transaction Limit Checker**
# - Problem Statement
#     - Create a function to validate daily transaction amount.
# - Rules
#     - Daily limit = ₹50,000
#     - Amount within limit → Approved
#     - Amount exceeds limit → Rejected
# - Real-Time Use
#     - Banking systems
#     - Fraud prevention systems
# - Expected Output Format
#     - Transaction Amount: 60000
#     Transaction Status: Rejected

# %%
#case 1: 45000 (approved)
def transaction_checker(amount):
    limit = 50000
    if amount <= limit:
        status = "Approved"
    else:
        status = "Rejected"
    print("Transaction Amount:", amount)
    print("Transaction Status:", status)

amount = int(input("Enter transaction amount: "))
transaction_checker(amount)
# Out:
# Transaction Amount: 45000
# Transaction Status: Approved

# %%
#case 2: 60000 (rejected)
def transaction_checker(amount):
    limit = 50000
    if amount <= limit:
        status = "Approved"
    else:
        status = "Rejected"
    print("Transaction Amount:", amount)
    print("Transaction Status:", status)

amount = int(input("Enter transaction amount: "))
transaction_checker(amount)
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# **Problem 9: E-Learning – Student Attendance Eligibility System**
# - Problem Statement
#     - Create a function to calculate attendance percentage and check exam eligibility.
# - Rules
#     - Attendance ≥ 75% → Eligible
#     - Attendance < 75% → Not Eligible
# - Real-Time Use
#     - Learning management systems
#     - Internship tracking platforms
# - Expected Output Format
#     - Attendance Percentage: 80.0
#     Exam Eligibility: Eligible

# %%
#case 1: Not eligible 
def attendance_checker(attendance_list):
    total_classes = len(attendance_list)
    attended = 0
    for status in attendance_list:
        if status == 1:
            attended += 1
    percentage = (attended / total_classes) * 100
    if percentage >= 75:
        eligibility = "Eligible"
    else:
        eligibility = "Not Eligible"
    print("Attendance Percentage:", percentage)
    print("Exam Eligibility:", eligibility)
user_input = input("Enter attendance (1 for Present, 0 for Absent) separated by spaces: ")
attendance = [int(x) for x in user_input.split()]
attendance_checker(attendance)
# Out:
# Attendance Percentage: 66.66666666666666
# Exam Eligibility: Not Eligible

# %%
#case 2: Eligible 
def attendance_checker(attendance_list):
    total_classes = len(attendance_list)
    attended = 0
    for status in attendance_list:
        if status == 1:
            attended += 1
    percentage = (attended / total_classes) * 100
    if percentage >= 75:
        eligibility = "Eligible"
    else:
        eligibility = "Not Eligible"
    print("Attendance Percentage:", percentage)
    print("Exam Eligibility:", eligibility)
user_input = input("Enter attendance (1 for Present, 0 for Absent) separated by spaces: ")
attendance = [int(x) for x in user_input.split()]
attendance_checker(attendance)
# Out:
# Attendance Percentage: 77.77777777777779
# Exam Eligibility: Eligible

# %% [markdown]
# **Problem 10: Smart Electricity Bill Analyzer**
# - Problem Statement
#     - You are building a smart electricity billing system for residential users.
#     - Create a function that calculates the electricity bill and classifies usage level based on units consumed.
# - Billing Rules
#     - First 100 units → ₹3 per unit
#     - Next 100 units (101–200) → ₹5 per unit
#     - Above 200 units → ₹7 per unit
# - Usage Classification
#     - Total bill < ₹500 → Low Usage
#     - ₹500 – ₹1500 → Moderate Usage
#     - ₹1500 → High Usage
# - Real-Time Use
#     - Smart meter systems
#     - Electricity board billing software
#     - Energy consumption analytics

# %%
def calculate_energy_charge(consumed_units):
    total_amount = 0

    # Slab-wise calculation
    if consumed_units <= 100:
        total_amount = consumed_units * 3
    elif consumed_units <= 200:
        total_amount = (100 * 3) + ((consumed_units - 100) * 5)
    else:
        total_amount = (100 * 3) + (100 * 5) + ((consumed_units - 200) * 7)

    # Consumption category
    if total_amount < 500:
        category = "Low Consumption"
    elif total_amount <= 1500:
        category = "Moderate Consumption"
    else:
        category = "High Consumption"
    return total_amount, category

units_used = int(input("Enter total electricity units consumed: ")) #Sample input: 250
amount_due, consumption_level = calculate_energy_charge(units_used)
print("Electricity Charge:", amount_due)
print("Consumption Level:", consumption_level)
# Out:
# Electricity Charge: 1150
# Consumption Level: Moderate Consumption
